# %%
import json

fd = open("record.json", "r")
js= fd.read()
fd. close()

record= json.loads(js)


print("Welcome to shop")


ui_prod = input("Enter the product Id: ")
ui_quan = int(input("Enter the quantity of the Product: "))

for i in record.keys():
    while ui_prod == i:
        if ui_quan <= record[i]['quant']:
            print("****************************************")
            print("             product:",record[ui_prod]['name'])
            print("               price:",record[ui_prod]['price'])
            print("         Expiry date:",record[ui_prod]['expiry'])
            print(" Manufacturing Brand:",record[ui_prod]['brand'])
            print("****************************************")
            print("----------BILLING DETAILS:---------- ")
            print("Total Amount: ",record[ui_prod]['price']*ui_quan) 
            print("Enjoy Your Day")
            print("Thank You. Visit Again")
            print("**********************************")
            record[ui_prod]["quant"] = record[ui_prod]["quant"] - ui_quan
        else:
            print("Sorry. Stock of product you enterd is: ",record[ui_prod]['quant'],"\nPlease accept our apologies for this inconvenience")
        break
if ui_prod not in record.keys():
    print("Sorry. No product found for ID: ",ui_prod,"\Please enter valid product ID")
    
    
js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()

## The sold items information is stored on sales.json
fd = open("sales.json",'r')
trans = fd.read()
fd.close()

sales = json.loads(trans)
num = len(sales)+1

sales[num] = {'prod':ui_prod, 'quant' : ui_quan, 'amount': record[ui_prod]['price'] * ui_quan}
sale = json.dumps(sales)

fd = open("sales.json",'w')
fd.write(sale)
fd.close()
# Out:
# Welcome to shop
# Enter the product Id: 033
# Enter the quantity of the Product: 4
# ****************************************
#              product: choclate ice cream
#                price: 50
#          Expiry date: 15/9/2022
#  Manufacturing Brand: amul
# ****************************************
# ----------BILLING DETAILS:----------
# Total Amount:  200
# Enjoy Your Day
# Thank You. Visit Again
# **********************************

# %%
record
# Out:
# {'003': {'brand': 'cadbury',
#   'expiry': '4/12/2023',
#   'name': 'perk',
#   'price': 20,
#   'quant': 98},
#  '004': {'brand': 'coco cola',
#   'expiry': '13/4/2025',
#   'name': 'sprite',
#   'price': 60,
#   'quant': 150},
#  '005': {'brand': 'cola',
#   'expiry': '3/3/2024',
#   'name': 'thumbsup',
#   'price': 70,
#   'quant': 179},
#  '006': {'brand': 'britannia',
#   'expiry': '15/7/2024',
#   'name': 'good day',
#   'price': 10,
#   'quant': 100},
#  '007': {'brand': 'brittania',
#   'expiry': '6/9/2022',
#   'name': 'marigold',
#   'price': 15,
#   'quant': 45},
#  '008': {'brand': 'parle g',
#   'expiry': '15/9/2023',
#   'name': 'pale g',
#   'price': 10,
#   'quant': 200},
#  '009': {'brand': 'cello',
#   'expiry': '6/8/2025',
#   'name': 'pen',
#   'price': 10,
#   'quant': 36},
#  '010': {'brand': 'natraj',
#   'expiry': '3/9/2025',
#   'name': 'pencil',
#   'price': 10,
#   'quant': 50},
#  '011': {'brand': 'camel',
#   'expiry': '3/9/2025',
#   'name': 'scale',
#   'price': 15,
#   'quant': 100},
#  '012': {'brand': 'faber castle',
#   'expiry': '24/9/2023',
#   'name': 'cryons',
#   'price': 50,
#   'quant': 20},
#  '013': {'brand': 'camel',
#   'expiry': '13/7/2025',
#   'name': 'sketches',
#   'price': 30,
#   'quant': 50},
#  '014': {'brand': 'colgate',
#   'expiry': '3/2/2023',
#   'name': 'colgate',
#   'price': 35,
#   'quant': 160},
#  '015': {'brand': 'pepsodent',
#   'expiry': '18/8/2023',
#   'name': 'pepsodent',
#   'price': 40,
#   'quant': 150},
#  '016': {'brand': 'pathanjali',
#   'expiry': '3/4/2023',
#   'name': 'pathanjali neem soap',
#   'price': 35,
#   'quant': 80},
#  '017': {'brand': 'unilever',
#   'expiry': '3/9/2023',
#   'name': 'surfexel',
#   'price': 50,
#   'quant': 140},
#  '018': {'brand': 'unilever',
#   'expiry': '3/9/2024',
#   'name': 'rin',
#   'price': 43,
#   'quant': 67},
#  '019': {'brand': 'dove',
#   'expiry': '28/7/2023',
#   'name': 'dove shampoo',
#   'price': 290,
#   'quant': 70},
#  '020': {'brand': 'himalaya',
#   'expiry': '3/9/2025',
#   'name': 'himalaya shampoo',
#   'price': 150,
#   'quant': 36},
#  '021': {'brand': 'karthika',
#   'expiry': '3/5/2022',
#   'name': 'karthika',
#   'price': 48,
#   'quant': 50},
#  '022': {'brand': 'cavinkare',
#   'expiry': '17/8/2022',
#   'name': 'meera',
#   'price': 190,
#   'quant': 67},
#  '023': {'brand': 'itc limited',
#   'expiry': '4/7/2022',
#   'name': 'bingo chips',
#   'price': 10,
#   'quant': 100},
#  '025': {'brand': 'lays',
#   'expiry': '3/8/2022',
#   'name': "lay's",
#   'price': 20,
#   'quant': 87},
#  '026': {'brand': 'corn puffs',
#   'expiry': '3/9/2025',
#   'name': 'kurkure',
#   'price': 20,
#   'quant': 200},
#  '027': {'brand': 'arnold',
#   'expiry': '3/3/2023',
#   'name': 'bread',
#   'price': 40,
#   'quant': 50},
#  '028': {'brand': 'oral b',
#   'expiry': '3/9/2026',
#   'name': 'tooth brush',
#   'price': 20,
#   'quant': 350},
#  '029': {'brand': 'heritage',
#   'expiry': '17/9/2022',
#   'name': 'heritage milk',
#   'price': 35,
#   'quant': 100},
#  '030': {'brand': 'jercy',
#   'expiry': '19/9/2022',
#   'name': 'jercy milk',
#   'price': 28,
#   'quant': 50},
#  '031': {'brand': 'masquti',
#   'expiry': '3/9/2022',
#   'name': 'masquti curd',
#   'price': 20,
#   'quant': 36},
#  '032': {'brand': 'cream bell',
#   'expiry': '28/9/2022',
#   'name': 'vennela ice cream',
#   'price': 40,
#   'quant': 30},
#  '033': {'brand': 'amul',
#   'expiry': '15/9/2022',
#   'name': 'choclate ice cream',
#   'price': 50,
#   'quant': 20},
#  '034': {'brand': 'cream bell',
#   'expiry': '3/6/2023',
#   'name': 'butterscotch ice cream',
#   'price': 25,
#   'quant': 50},
#  '035': {'brand': 'amul',
#   'expiry': '14/7/2022',
#   'name': 'oreo ice cream',
#   'price': 30,
#   'quant': 10},
#  '101': {'brand': 'nestle',
#   'expiry': '3/9/2022',
#   'name': 'kitkat',
#   'price': 20,
#   'quant': 40},
#  '102': {'brand': 'cadbury',
#   'expiry': '27/8/2025',
#   'name': 'dairy milk',
#   'price': 100,
#   'quant': 50}}

# %% [markdown]
# **update inventory after purchase**

# %%
sales = {1:{"prod_id":ui_prod,"quant":ui_quan,"amount":record[ui_prod]["price"]*ui_quan}}
sal = json.dumps(sales)

fd = open("sales.json","w")
fd.write(sal)
fd.close()
